# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# import gdown as gd

# %%
# raw_link = 'https://drive.google.com/file/d/1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X/view?usp=drive_link'
# id = '1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X'

# gd.download(id = id, output = 'crime_work.csv', quiet=False)

# df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head()
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X
# From (redirected): https://drive.google.com/uc?id=1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X&confirm=t&uuid=d7227449-6170-4506-8f2f-f0ba9c1e8224
# To: c:\Users\DELL\Desktop\New\AI-D-D\WEEK_6\TASK_FOLDER\crime_work.csv
#   0%|          | 0.00/460M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 raw_link = 'https://drive.google.com/file/d/1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X/view?usp=drive_link'
#       2 id = '1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X'
# ----> 4 gd.download(id = id, output = 'crime_work.csv', quiet=False)
#       6 df1 = pd.read_csv('crime_work.csv', sep=',')
#       7 df1.head()
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\gdown\download.py:368, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     366     pbar = tqdm.tqdm(total=total, unit="B", initial=start_size, unit_scale=True)
#     367 t_start = time.time()
# --> 368 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     369     f.write(chunk)
#     370     if not quiet:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# url = 'https://drive.google.com/file/d/1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X/view?usp=drive_link'
# id='1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X'
# gd.download(url,output='crime_work.csv',quiet=False)

# df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head()
# Out:
# c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\gdown\parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X
#   warnings.warn(
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[15], line 5
#       2 id='1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X'
#       3 gd.download(url,output='crime_work.csv',quiet=True)
# ----> 5 df1 = pd.read_csv('crime_work.csv', sep=',')
#       6 df1.head()
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 3, saw 4282

# %%
# df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df1 = pd.read_csv('crime_work.csv', sep=',')
#       2 df1.head()
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 3, saw 4233

# %% [markdown]
# <!-- df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head() -->

# %%
# %pip install dask pyarrow
# import dask.dataframe as dd
# import pyarrow as pa
# Out:
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (1.6 MB/26.1 MB, attempt 1)
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (10.7 MB/26.1 MB, attempt 2)
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (13.1 MB/26.1 MB, attempt 3)
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (13.1 MB/26.1 MB, attempt 4)
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (13.1 MB/26.1 MB, attempt 5)
# WARNING: Connection timed out while downloading.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\DELL\\AppData\\Local\\Temp\\pip-unpack-x29265h4\\pyarrow-21.0.0-cp313-cp313-win_amd64.whl'
# Check the permissions.
# Collecting dask
#   Using cached dask-2025.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting pyarrow
#   Using cached pyarrow-21.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Collecting click>=8.1 (from dask)
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloudpickle>=3.0.0 (from dask)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting fsspec>=2021.09.0 (from dask)
#   Using cached fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\desktop\new\.venv\lib\site-packages (from dask) (25.0)
# Collecting partd>=1.4.0 (from dask)
#   Using cached partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from dask)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting toolz>=0.10.0 (from dask)
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\dell\desktop\new\.venv\lib\site-packages (from click>=8.1->dask) (0.4.6)
# Collecting locket (from partd>=1.4.0->dask)
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Using cached dask-2025.9.1-py3-none-any.whl (1.5 MB)
# Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl (26.1 MB)
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X
# From (redirected): https://drive.google.com/uc?id=1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X&confirm=t&uuid=fdec9573-67f4-4f40-9222-b3f02ab3fb3e
# To: c:\Users\DELL\Desktop\New\AI-D-D\WEEK_6\TASK_FOLDER\crime.zip
#   0%|          | 1.57M/460M [03:40<18:32:07, 6.87kB/s]
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:779, in HTTPResponse._error_catcher(self)
#     778 try:
# --> 779     yield
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1090 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091     data = self.read(amt=amt, decode_content=decode_content)
#    1093     if data:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:903, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
# --> 903 with self._error_catcher():
#     904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:806, in HTTPResponse._error_catcher(self)
#     805 except (HTTPException, OSError) as e:
# --> 806     raise ProtocolError(f"Connection broken: {e!r}", e) from e
#     808 # If no exception is thrown, we should avoid cleaning up
#     809 # unnecessarily.
#
# ProtocolError: ("Connection broken: ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None)", ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[1], line 12
#       8 file_path = "crime.zip"
#      10 #loading the dataset
# ---> 12 gdown.download(f"https://drive.google.com/uc?id={id}", file_path,quiet=False)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\gdown\download.py:368, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     366     pbar = tqdm.tqdm(total=total, unit="B", initial=start_size, unit_scale=True)
#     367 t_start = time.time()
# --> 368 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     369     f.write(chunk)
#     370     if not quiet:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\requests\models.py:822, in Response.iter_content.<locals>.generate()
#     820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
# --> 822     raise ChunkedEncodingError(e)
#     823 except DecodeError as e:
#     824     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None)", ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))

# %%
import kagglehub

path = kagglehub.dataset_download("utkarshx27/crimes-2001-to-present")

print("path to dataset files:", path)
# Out:
# Resuming download from 6291456 bytes (453578563 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/utkarshx27/crimes-2001-to-present?dataset_version_number=1 (6291456/459870019) bytes left.
#   4%|▍         | 17.0M/439M [08:53<5:40:36, 21.6kB/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:779, in HTTPResponse._error_catcher(self)
#     778 try:
# --> 779     yield
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1090 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091     data = self.read(amt=amt, decode_content=decode_content)
#    1093     if data:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:903, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
# --> 903 with self._error_catcher():
#     904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\urllib3\response.py:784, in HTTPResponse._error_catcher(self)
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
# --> 784     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     786 except BaseSSLError as e:
#     787     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='storage.googleapis.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 3
#       1 import kagglehub
# ----> 3 path = kagglehub.dataset_download("utkarshx27/crimes-2001-to-present")
#       5 print("path to dataset files:", path)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\kagglehub\datasets.py:43, in dataset_download(handle, path, force_download)
#      41 h = parse_dataset_handle(handle)
#      42 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44 return path
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)     27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\kagglehub\http_resolver.py:130, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     127 os.makedirs(os.path.dirname(archive_path), exist_ok=True)
#     129 # First, we download the archive.
# --> 130 api_client.download_file(url_path, archive_path, h)
#     132 _extract_archive(archive_path, out_path)
#     134 # Delete the archive
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\kagglehub\clients.py:214, in KaggleApiV1Client.download_file(self, path, out_file, resource_handle, cached_path, extract_auto_compressed_file)
#     206     with requests.get(
#     207         response.url,  # URL after redirection
#     208         stream=True,
#    (...)    211         headers={"Range": f"bytes={size_read}-"},
#     212     ) as resumed_response:
#     213         logger.info(f"Resuming download from {url} ({size_read}/{total_size}) bytes left.")
# --> 214         _download_file(resumed_response, out_file, size_read, total_size, hash_object)
#     215 else:
#     216     logger.info(f"Downloading from {url}...")
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\kagglehub\clients.py:276, in _download_file(response, out_file, size_read, total_size, hash_object)
#     274 with tqdm(total=total_size, initial=size_read, unit="B", unit_scale=True, unit_divisor=1024) as progress_bar:
#     275     with open(out_file, open_mode) as f:
# --> 276         for chunk in response.iter_content(CHUNK_SIZE):
#     277             f.write(chunk)
#     278             if hash_object:
#
# File c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\requests\models.py:826, in Response.iter_content.<locals>.generate()
#     824     raise ContentDecodingError(e)
#     825 except ReadTimeoutError as e:
# --> 826     raise ConnectionError(e)
#     827 except SSLError as e:
#     828     raise RequestsSSLError(e)
#
# ConnectionError: HTTPSConnectionPool(host='storage.googleapis.com', port=443): Read timed out.
