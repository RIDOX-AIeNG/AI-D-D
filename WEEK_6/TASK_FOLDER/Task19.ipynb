# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# %pip install gdown
# import gdown as gd

# %%
# raw_link = 'https://drive.google.com/file/d/1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X/view?usp=drive_link'
# id = '1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X'

# gd.download(id = id, output = 'crime_work.csv', quiet=False)

# df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head()

# %%
# url = 'https://drive.google.com/file/d/1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X/view?usp=drive_link'
# id='1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X'
# gd.download(url,output='crime_work.csv',quiet=False)

# df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head()

# %%
# df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head()

# %% [markdown]
# <!-- df1 = pd.read_csv('crime_work.csv', sep=',')
# df1.head() -->

# %%
# %pip install dask pyarrow
# import dask.dataframe as dd
# import pyarrow as pa

# %%
# #import lib for loading dataset
# import gdown
# import zipfile

# #importing the dataset from google drive
# raw_link = 'https://drive.google.com/file/d/1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X/view?usp=drive_link'
# id ='1ib1PWK_3oaaSfThqfnfSoPZq7vA1g33X'
# file_path = "crime.zip"

# #loading the dataset

# gdown.download(f"https://drive.google.com/uc?id={id}", file_path,quiet=False)

# %% [markdown]
# ## Injesting the data

# %%
import kagglehub

path = kagglehub.dataset_download("utkarshx27/crimes-2001-to-present")

print("path to dataset files:", path)
# Out:
# path to dataset files: C:\Users\DELL\.cache\kagglehub\datasets\utkarshx27\crimes-2001-to-present\versions\1

# %%
df= pd.read_csv(r'C:\Users\DELL\.cache\kagglehub\datasets\utkarshx27\crimes-2001-to-present\versions\1\Crimes_-_2001_to_Present.csv')
# df.head(5)

# %% [markdown]
# ## Pleliminary data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7784664 entries, 0 to 7784663
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %%
df.head(5)
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# ...

# %%
df.isna().sum()
# Out:
# ID                           0
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description     10381
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    47
# Ward                    614848
# Community Area          613476
# FBI Code                     0
# X Coordinate             86848
# Y Coordinate             86848
# Year                         0
# Updated On                   0
# Latitude                 86848
# Longitude                86848
# Location                 86848
# dtype: int64

# %%
df.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  7.784664e+06  7.784664e+06  7.784617e+06  7.169816e+06    7.171188e+06
# mean   7.026439e+06  1.185918e+03  1.129466e+01  2.275420e+01    3.748472e+01
# std    3.502657e+06  7.031335e+02  6.952422e+00  1.385106e+01    2.154115e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    3.792574e+06  6.210000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    7.029327e+06  1.034000e+03  1.000000e+01  2.300000e+01    3.200000e+01
# 75%    1.013113e+07  1.731000e+03  1.700000e+01  3.400000e+01    5.700000e+01
# max    1.305643e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  7.697816e+06  7.697816e+06  7.784664e+06  7.697816e+06  7.697816e+06
# mean   1.164601e+06  1.885783e+06  2.009944e+03  4.184218e+01 -8.767149e+01
# ...

# %%
#Checking for missing values in case number
df[df['Case Number'].isna() == True]
# Out:
#               ID Case Number                    Date                 Block  \
# 4981841  7049552         NaN  07/30/2009 03:00:00 AM    058XX N PAULINA ST
# 5286601  7610078         NaN  07/16/2010 02:56:00 PM  005XX W VAN BUREN ST
# 5992794  8475075         NaN  02/08/2012 10:00:00 PM   032XX N KILDARE AVE
# 7488610  7014449         NaN  07/10/2009 11:00:00 AM    082XX S HARPER AVE
#
#          IUCR     Primary Type     Description Location Description  Arrest  \
# 4981841  1320  CRIMINAL DAMAGE      TO VEHICLE               STREET   False
# 5286601  0460          BATTERY          SIMPLE             SIDEWALK    True
# 5992794  0620         BURGLARY  UNLAWFUL ENTRY            APARTMENT   False
# 7488610  0560          ASSAULT          SIMPLE               STREET   False
#
#          Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 4981841     False  ...  40.0            77.0        14     1164170.0
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df_copy = df.copy()

# %%
#drop missing values
df.dropna(inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                1642148
# BATTERY                              1422913
# CRIMINAL DAMAGE                       887266
# NARCOTICS                             747633
# ASSAULT                               507296
# OTHER OFFENSE                         483642
# BURGLARY                              424397
# MOTOR VEHICLE THEFT                   375495
# DECEPTIVE PRACTICE                    344940
# ROBBERY                               292334
# CRIMINAL TRESPASS                     214316
# WEAPONS VIOLATION                     106418
# PROSTITUTION                           69840
# OFFENSE INVOLVING CHILDREN             55719
# PUBLIC PEACE VIOLATION                 52325
# SEX OFFENSE                            30683
# CRIM SEXUAL ASSAULT                    27631
# INTERFERENCE WITH PUBLIC OFFICER       18392
# LIQUOR LAW VIOLATION                   14901
# GAMBLING                               14618
# ...

# %%
df['Arrest'].value_counts()
# Out:
# Arrest
# False    5749900
# True     2034764
# Name: count, dtype: int64
