# %% [markdown]
# ## Part 4: VSCODE Connection to Database

# %%
import pandas as pd
from sqlalchemy import create_engine

USER = 'postgres'
PASSWORD = 'admin'
HOST = 'localhost'
PORT = '5433'
DB = 'library_db'

# create datbase connection
engine = create_engine(f'postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}')

# %%
# Load all the database
books = pd.read_sql("SELECT * FROM Books", engine)
authors = pd.read_sql("SELECT * FROM Authors", engine)
book_orders = pd.read_sql("SELECT * FROM BookOrders", engine)
borrow_history = pd.read_sql("SELECT * FROM Borrow_History", engine)
members = pd.read_sql("SELECT * FROM Members", engine)
library_staff = pd.read_sql("SELECT * FROM Library_Staff", engine)
departments = pd.read_sql("SELECT * FROM Departments", engine)

# %%
books.head()
# Out:
#    book_id                title  author_id              genre  \
# 0        1  The Handmaid's Tale          1  Dystopian Fiction
# 1        2            Cat's Eye          1   Literary Fiction
# 2        3   The Blind Assassin          1   Literary Fiction
# 3        4       Norwegian Wood          2   Literary Fiction
# 4        5   Kafka on the Shore          2    Magical Realism
#
#   date_of_publication             publisher           isbn language  \
# 0          1985-08-01  McClelland & Stewart  9780771008795  English
# 1          1988-09-01  McClelland & Stewart  9780771008801  English
# 2          2000-09-01  McClelland & Stewart  9780771008818  English
# 3          1987-09-04              Kodansha  9784062748687  English
# 4          2002-09-12            Shinchosha  9784101001548  English
#
#    available_copies age_rating
# 0                 3        16+
# 1                 2        16+
# 2                 1        18+
# 3                 2        18+
# 4                 3        16+

# %%
# Display the authors
authors.head()
# Out:
#    author_id               author_name country_of_origin  \
# 0          1           Margaret Atwood            Canada
# 1          2           Haruki Murakami             Japan
# 2          3  Chimamanda Ngozi Adichie           Nigeria
# 3          4            Elena Ferrante             Italy
# 4          5            Salman Rushdie             India
#
#    number_of_books_written
# 0                       23
# 1                       18
# 2                        7
# 3                       12
# 4                       19

# %%
# Display the book_orders
book_orders.head()
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, book_id, cost, quantity, supplydate, fulfillment_status, supplier_name]
# Index: []

# %%
# Display the members
members.head()
# Out:
#    member_id             name  gender            email_address phone_number  \
# 0          1    Sarah Johnson  FEMALE  sarah.johnson@email.com         -677
# 1          2     Michael Chen    MALE         m.chen@gmail.com         -788
# 2          3  Emily Rodriguez  FEMALE      emily.r@hotmail.com         -899
# 3          4   David Thompson    MALE     d.thompson@yahoo.com        -1010
# 4          5        Lisa Wang  FEMALE    lisa.wang@outlook.com        -1121
#
#                          address  age type_of_membership date_of_membership  \
# 0  123 Oak Street Springfield IL   28            premium         2022-01-15
# 1     456 Pine Avenue Chicago IL   34           standard         2021-03-22
# 2    789 Maple Drive Evanston IL   22            student         2023-09-01
# 3   321 Elm Street Naperville IL   45            premium         2020-06-10
# 4       654 Cedar Lane Aurora IL   31           standard         2022-08-18
#
#    status
# 0  active
# 1  active
# 2  active
# 3  active
# 4  active

# %%
# Display the borrow history
borrow_history.head()
# Out:
#    borrowed_id  book_id  member_id borrow_date return_date
# 0            1        1          1  2024-01-15  2024-02-05
# 1            2        2          3  2024-02-10  2024-03-02
# 2            3       22          2  2024-01-22  2024-02-12
# 3            4       30          9  2024-03-05  2024-03-25
# 4            5        7          4  2024-02-18  2024-03-10

# %%
# Display the library staff
library_staff.head()
# Out:
#    staff_id             name             job_title  department_id  gender  \
# 0         1   Jennifer Walsh        Head Librarian              1  FEMALE
# 1         2   Mark Patterson   Assistant Librarian              1    MALE
# 2         3   Rebecca Foster  Children's Librarian              2  FEMALE
# 3         4  Thomas Anderson   Reference Librarian              3    MALE
# 4         5   Maria Gonzalez   Circulation Manager              4  FEMALE
#
#                             address phone_number   hire_date  manager_id
# 0   892 Library Lane Springfield IL        -2555  2018-01-15         NaN
# 1        445 Book Street Chicago IL        -2556  2019-03-10         1.0
# 2      678 Story Avenue Evanston IL        -2557  2020-06-22         1.0
# 3  234 Research Drive Naperville IL        -2558  2021-01-08         1.0
# 4       567 Checkout Lane Aurora IL        -2559  2019-09-15         1.0

# %%
# Display the departments
departments.head()
# Out:
#    dept_id            department_name     manager_name
# 0        1             Administration   Jennifer Walsh
# 1        2  Children & Youth Services   Rebecca Foster
# 2        3       Reference & Research  Thomas Anderson
# 3        4                Circulation   Maria Gonzalez
# 4        5         Technical Services    Kevin O'Brien

# %% [markdown]
# QUERY 1: List all books published after 2015 along with their authors' names.

# %%
# Display athe columns in table 'bookss'
books.columns
# Out:
# Index(['book_id', 'title', 'author_id', 'genre', 'date_of_publication',
#        'publisher', 'isbn', 'language', 'available_copies', 'age_rating'],
#       dtype='object')

# %%
authors.columns
# Out:
# Index(['author_id', 'author_name', 'country_of_origin',
#        'number_of_books_written'],
#       dtype='object')

# %%
# Merge table books and authors 
books_authors = pd.merge(books, authors, on='author_id', how='inner')
books_authors.head()
# Out:
#    book_id                title  author_id              genre  \
# 0        1  The Handmaid's Tale          1  Dystopian Fiction
# 1        2            Cat's Eye          1   Literary Fiction
# 2        3   The Blind Assassin          1   Literary Fiction
# 3        4       Norwegian Wood          2   Literary Fiction
# 4        5   Kafka on the Shore          2    Magical Realism
#
#   date_of_publication             publisher           isbn language  \
# 0          1985-08-01  McClelland & Stewart  9780771008795  English
# 1          1988-09-01  McClelland & Stewart  9780771008801  English
# 2          2000-09-01  McClelland & Stewart  9780771008818  English
# 3          1987-09-04              Kodansha  9784062748687  English
# 4          2002-09-12            Shinchosha  9784101001548  English
#
#    available_copies age_rating      author_name country_of_origin  \
# 0                 3        16+  Margaret Atwood            Canada
# 1                 2        16+  Margaret Atwood            Canada
# 2                 1        18+  Margaret Atwood            Canada
# 3                 2        18+  Haruki Murakami             Japan
# 4                 3        16+  Haruki Murakami             Japan
#
#    number_of_books_written
# 0                       23
# 1                       23
# 2                       23
# 3                       18
# 4                       18

# %%
# Converting to the date to datetime
books_authors['date_of_publication'] = pd.to_datetime(books_authors['date_of_publication'])
books_authors.dtypes
# Out:
# book_id                             int64
# title                              object
# author_id                           int64
# genre                              object
# date_of_publication        datetime64[ns]
# publisher                          object
# isbn                               object
# language                           object
# available_copies                    int64
# age_rating                         object
# author_name                        object
# country_of_origin                  object
# number_of_books_written             int64
# dtype: object

# %%
# List all books published after 2015 along with their authors' names.
books_published_2015 = books_authors[books_authors['date_of_publication'].dt.year > 2015]
books_published_2015
# Out:
#     book_id                            title  author_id  \
# 23       24  21 Lessons for the 21st Century          8
# 47       48                       Sea Prayer         13
# 62       63                Klara and the Sun         20
# 72       73                  Manhattan Beach         25
# 73       74         The Underground Railroad         26
# 75       76             An American Marriage         27
# 83       84                         Educated         31
# 84       85                         Becoming         32
# 85       86                  A Promised Land         33
#
#                     genre date_of_publication        publisher           isbn  \
# 23            Non-fiction          2018-08-21   Spiegel & Grau  9780525512172
# 47  Children's Literature          2018-09-18  Riverhead Books  9780525554943
# 62        Science Fiction          2021-03-02    Faber & Faber  9780571364886
# 72     Historical Fiction          2017-10-03         Scribner  9781476746678
# 73     Historical Fiction          2016-08-02        Doubleday  9780385542364
# 75       Literary Fiction          2018-02-06  Algonquin Books  9781616201340
# 83                 Memoir          2018-02-20     Random House  9780399590504
# 84                 Memoir          2018-11-13            Crown  9781524763138
# 85                 Memoir          2020-11-17            Crown  9781524763169
#
#    language  available_copies age_rating        author_name country_of_origin  \
# 23  English                 3        16+  Yuval Noah Harari            Israel
# 47  English                 2         8+    Khaled Hosseini       Afghanistan
# 62  English                 4        14+     Kazuo Ishiguro             Japan
# 72  English                 1        16+      Jennifer Egan     United States
# 73  English                 3        18+   Colson Whitehead     United States
# 75  English                 2        18+       Tayari Jones     United States
# 83  English                 5        16+      Tara Westover     United States
# 84  English                 6        14+     Michelle Obama     United States
# 85  English                 4        14+       Barack Obama     United States
#
#     number_of_books_written
# 23                        4
# 47                        4
# 62                       10
# 72                        7
# 73                        9
# 75                        5
# 83                        2
# 84                        2
# 85                        3

# %%
# Grouping all books published later than 2015 by the author's name
books_by_authors_2015 = books_published_2015[['date_of_publication', 'title', 'author_name']]
books_by_authors_2015
# Out:
#    date_of_publication                            title        author_name
# 23          2018-08-21  21 Lessons for the 21st Century  Yuval Noah Harari
# 47          2018-09-18                       Sea Prayer    Khaled Hosseini
# 62          2021-03-02                Klara and the Sun     Kazuo Ishiguro
# 72          2017-10-03                  Manhattan Beach      Jennifer Egan
# 73          2016-08-02         The Underground Railroad   Colson Whitehead
# 75          2018-02-06             An American Marriage       Tayari Jones
# 83          2018-02-20                         Educated      Tara Westover
# 84          2018-11-13                         Becoming     Michelle Obama
# 85          2020-11-17                  A Promised Land       Barack Obama

# %% [markdown]
# QUERY 2. Find all members who joined in the last 2 years and have a 'Premium' membership

# %%
## Converting to the date to datetime
members['date_of_membership'] = pd.to_datetime(members['date_of_membership'])

# %%
# Display members from last two year
last_two_years= members[(members['date_of_membership'].dt.year > 2021) & (members['type_of_membership']== 'premium')]
last_two_years
# Out:
#     member_id               name  gender            email_address  \
# 0           1      Sarah Johnson  FEMALE  sarah.johnson@email.com
# 6           7       Amanda Davis  FEMALE       amanda.d@gmail.com
# 18         19    Ashley Robinson  FEMALE   a.robinson@outlook.com
# 28         29        Kayla Adams  FEMALE      k.adams@outlook.com
# 31         32      Trevor Nelson    MALE     t.nelson@hotmail.com
# 38         39  Danielle Campbell  FEMALE   d.campbell@outlook.com
# 41         42        Ian Edwards    MALE    i.edwards@hotmail.com
# 48         49        Sierra Cook  FEMALE       s.cook@outlook.com
# 58         59      Jenna Ramirez  FEMALE    j.ramirez@outlook.com
# 61         62      Xavier Brooks    MALE     x.brooks@hotmail.com
# 68         69          Luna Ross  FEMALE       l.ross@outlook.com
#
#    phone_number                          address  age type_of_membership  \
# 0          -677    123 Oak Street Springfield IL   28            premium
# 6         -1343      147 Willow Street Peoria IL   26            premium
# 18        -2455  814 Poplar Avenue Naperville IL   32            premium
# 28        -3455    926 Poplar Lane Naperville IL   33            premium
# 31        -3788          359 Oak Drive Peoria IL   28            premium
# 38        -4455  138 Poplar Street Naperville IL   31            premium
# 41        -4788         462 Oak Avenue Peoria IL   29            premium
# 48        -5455   241 Poplar Drive Naperville IL   32            premium
# 58        -6455    363 Poplar Lane Naperville IL   33            premium
# 61        -6788           696 Oak Lane Peoria IL   32            premium
# 68        -7455  475 Poplar Avenue Naperville IL   29            premium
#
#    date_of_membership  status
# 0          2022-01-15  active
# 6          2023-02-14  active
# 18         2022-02-28  active
# 28         2022-06-18  active
# 31         2022-09-14  active
# 38         2022-04-07  active
# 41         2022-07-21  active
# 48         2022-11-25  active
# 58         2022-08-14  active
# 61         2022-09-23  active
# 68         2022-05-24  active

# %%
# Grouping the premium members who joined in the  last years 
premium_members_two_years = last_two_years[['member_id', 'name', 'date_of_membership', 'type_of_membership', 'status']] 
premium_members_two_years
# Out:
#     member_id               name date_of_membership type_of_membership  status
# 0           1      Sarah Johnson         2022-01-15            premium  active
# 6           7       Amanda Davis         2023-02-14            premium  active
# 18         19    Ashley Robinson         2022-02-28            premium  active
# 28         29        Kayla Adams         2022-06-18            premium  active
# 31         32      Trevor Nelson         2022-09-14            premium  active
# 38         39  Danielle Campbell         2022-04-07            premium  active
# 41         42        Ian Edwards         2022-07-21            premium  active
# 48         49        Sierra Cook         2022-11-25            premium  active
# 58         59      Jenna Ramirez         2022-08-14            premium  active
# 61         62      Xavier Brooks         2022-09-23            premium  active
# 68         69          Luna Ross         2022-05-24            premium  active

# %% [markdown]
# Query 3. Display the total number of books written by each author, ordered by count (descending)

# %%
# Displaying the number of books written by each author
authors_by_books = authors.groupby('author_name')['number_of_books_written'].sum().sort_values(ascending=False)
authors_by_books
# Out:
# author_name
# Isaac Asimov                500
# Agatha Christie              85
# Stephen King                 64
# Philip K. Dick               44
# Terry Pratchett              41
# Neil Gaiman                  35
# Arthur C. Clarke             33
# Paulo Coelho                 30
# Brandon Sanderson            28
# Ray Bradbury                 27
# Bill Bryson                  25
# Isabel Allende               25
# Margaret Atwood              23
# Robin Hobb                   22
# Ursula K. Le Guin            21
# Salman Rushdie               19
# Haruki Murakami              18
# George R.R. Martin           15
# Gabriel García Márquez       15
# J.K. Rowling                 14
# Kurt Vonnegut                14
# Elena Ferrante               12
# Douglas Adams                12
# Octavio Paz                  12
# Toni Morrison                11
# Kazuo Ishiguro               10
# Umberto Eco                   9
# Colson Whitehead              9
# Milan Kundera                 8
# Mary Roach                    8
# Ayn Rand                      8
# David Foster Wallace          8
# Amy Tan                       8
# Chimamanda Ngozi Adichie      7
# Jennifer Egan                 7
# Malcolm Gladwell              7
# Zadie Smith                   6
# Jhumpa Lahiri                 6
# Maxine Hong Kingston          6
# Jonathan Franzen              5
# Chinua Achebe                 5
# Tayari Jones                  5
# Yuval Noah Harari             4
# Donna Tartt                   4
# Khaled Hosseini               4
# Barack Obama                  3
# Terry Gilliam                 3
# Patrick Rothfuss              3
# Michelle Obama                2
# Tara Westover                 2
# Name: number_of_books_written, dtype: int64

# %%
# Displaying the total number of books written by each author, ordered by count (descending)
total_no_books_written = authors[['author_id', 'author_name', 'number_of_books_written']]
total_no_books_written_table = total_no_books_written.sort_values(by='number_of_books_written', ascending=False)
total_no_books_written_table
# Out:
#     author_id               author_name  number_of_books_written
# 43         44              Isaac Asimov                      500
# 10         11           Agatha Christie                       85
# 8           9              Stephen King                       64
# 44         45            Philip K. Dick                       44
# 37         38           Terry Pratchett                       41
# 36         37               Neil Gaiman                       35
# 45         46          Arthur C. Clarke                       33
# 11         12              Paulo Coelho                       30
# 39         40         Brandon Sanderson                       28
# 46         47              Ray Bradbury                       27
# 34         35               Bill Bryson                       25
# 13         14            Isabel Allende                       25
# 0           1           Margaret Atwood                       23
# 41         42                Robin Hobb                       22
# 42         43         Ursula K. Le Guin                       21
# 4           5            Salman Rushdie                       19
# 1           2           Haruki Murakami                       18
# 6           7    Gabriel García Márquez                       15
# 38         39        George R.R. Martin                       15
# 9          10              J.K. Rowling                       14
# 47         48             Kurt Vonnegut                       14
# 3           4            Elena Ferrante                       12
# 48         49             Douglas Adams                       12
# 16         17               Octavio Paz                       12
# 5           6             Toni Morrison                       11
# 19         20            Kazuo Ishiguro                       10
# 25         26          Colson Whitehead                        9
# 17         18               Umberto Eco                        9
# 18         19             Milan Kundera                        8
# 23         24      David Foster Wallace                        8
# 14         15                  Ayn Rand                        8
# 35         36                Mary Roach                        8
# 28         29                   Amy Tan                        8
# 2           3  Chimamanda Ngozi Adichie                        7
# 33         34          Malcolm Gladwell                        7
# 24         25             Jennifer Egan                        7
# 27         28             Jhumpa Lahiri                        6
# 20         21               Zadie Smith                        6
# 29         30      Maxine Hong Kingston                        6
# 21         22          Jonathan Franzen                        5
# 15         16             Chinua Achebe                        5
# 26         27              Tayari Jones                        5
# 12         13           Khaled Hosseini                        4
# 7           8         Yuval Noah Harari                        4
# 22         23               Donna Tartt                        4
# 32         33              Barack Obama                        3
# 40         41          Patrick Rothfuss                        3
# 49         50             Terry Gilliam                        3
# 30         31             Tara Westover                        2
# 31         32            Michelle Obama                        2

# %% [markdown]
# Query 4. Show all currently borrowed books (books with no return date) along with the member's name and borrow date

# %%
# Print the columns in borrow history 
borrow_history.columns
# Out:
# Index(['borrowed_id', 'book_id', 'member_id', 'borrow_date', 'return_date'], dtype='object')

# %%
# Merge the members and borrow history
borrow_members = pd.merge(members, borrow_history, on='member_id', how='inner')
borrow_members
# Out:
#      member_id           name  gender            email_address phone_number  \
# 0            1  Sarah Johnson  FEMALE  sarah.johnson@email.com         -677
# 1            1  Sarah Johnson  FEMALE  sarah.johnson@email.com         -677
# 2            1  Sarah Johnson  FEMALE  sarah.johnson@email.com         -677
# 3            2   Michael Chen    MALE         m.chen@gmail.com         -788
# 4            2   Michael Chen    MALE         m.chen@gmail.com         -788
# ..         ...            ...     ...                      ...          ...
# 145         71   Nova Coleman  FEMALE      n.coleman@gmail.com        -7677
# 146         72  Orion Jenkins    MALE    o.jenkins@hotmail.com        -7788
# 147         73   Willow Perry  FEMALE        w.perry@yahoo.com        -7899
# 148         74   Atlas Powell    MALE     a.powell@outlook.com        -8010
# 149         75      Sage Long  FEMALE         s.long@email.com        -8121
#
#                            address  age type_of_membership date_of_membership  \
# 0    123 Oak Street Springfield IL   28            premium         2022-01-15
# 1    123 Oak Street Springfield IL   28            premium         2022-01-15
# 2    123 Oak Street Springfield IL   28            premium         2022-01-15
# 3       456 Pine Avenue Chicago IL   34           standard         2021-03-22
# 4       456 Pine Avenue Chicago IL   34           standard         2021-03-22
# ..                             ...  ...                ...                ...
# 145     697 Pine Drive Rockford IL   26            student         2023-08-20
# 146       719 Oak Avenue Peoria IL   33            premium         2021-10-03
# 147     831 Maple Street Joliet IL   30           standard         2022-07-16
# 148     942 Cedar Lane Waukegan IL   35           standard         2021-09-28
# 149   143 Elm Avenue Schaumburg IL   28            student         2023-04-11
#
#      status  borrowed_id  book_id borrow_date return_date
# 0    active            1        1  2024-01-15  2024-02-05
# 1    active            7       19  2024-02-20  2024-03-15
# 2    active           81       37  2024-02-05  2024-02-25
# 3    active            3       22  2024-01-22  2024-02-12
# 4    active           11       10  2024-03-10  2024-04-05
# ..      ...          ...      ...         ...         ...
# 145  active           76       21  2024-01-30  2024-02-20
# 146  active           77       47  2024-02-15  2024-03-07
# 147  active           78       74  2024-03-22  2024-04-12
# 148  active           79       89  2024-02-28  2024-03-20
# 149  active           80       14  2024-03-30        None
#
# [150 rows x 14 columns]

# %%
borrowed_books = borrow_members[borrow_members["return_date"] == "null"]
borrowed_books
# Out:
# Empty DataFrame
# Columns: [member_id, name, gender, email_address, phone_number, address, age, type_of_membership, date_of_membership, status, borrowed_id, book_id, borrow_date, return_date]
# Index: []

# %%
# Display all currently borrowed books with no return date along with the member's name and borrow date
no_of_borrowed_books = borrowed_books[['member_id', 'name', 'book_id', 'borrow_date', 'return_date']]
no_of_borrowed_books
# Out:
# Empty DataFrame
# Columns: [member_id, name, book_id, borrow_date, return_date]
# Index: []

# %% [markdown]
# Query 5. List all library staff members working in the 'Circulation' department.

# %%
# View the columns in librarystaff table
library_staff.columns
# Out:
# Index(['staff_id', 'name', 'job_title', 'department_id', 'gender', 'address',
#        'phone_number', 'hire_date', 'manager_id'],
#       dtype='object')

# %%
# View the columns in departments
departments.columns
# Out:
# Index(['dept_id', 'department_name', 'manager_name'], dtype='object')

# %%
# Merge the library_staff with the departments
library_depts = pd.merge(library_staff, departments, on='dept_id', how='inner')
library_depts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16976\1592760687.py in ?()
#       1 # Merge the library_staff with the departments
# ----> 2 library_depts = pd.merge(library_staff, departments, on='dept_id', how='inner')
#       3 library_depts
#
# c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1307                     if lk is not None:
#    1308                         # Then we're either Hashable or a wrong-length arraylike,
#    1309                         #  the latter of which will raise
#    1310                         lk = cast(Hashable, lk)
# -> 1311                         left_keys.append(left._get_label_or_level_values(lk))
#    1312                         join_names.append(lk)
#    1313                     else:
#    1314                         # work-around for merge_asof(left_index=True)
#
# c:\Users\DELL\Desktop\New\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'dept_id'
