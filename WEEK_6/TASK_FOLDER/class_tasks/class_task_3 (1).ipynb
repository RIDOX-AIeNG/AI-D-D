# %% [markdown]
# NAME: Osho Ridwanullah Ayomide
#
#
# Track: AI ENGINEERING
#
# CLASS TASK 2
# ```
# Compute the following
# A = [[2,-1],[0,3]] B = [[1,4],[-2,5]]
#
# (A)
#
# cA = 2[[2,-1],[0,3]]
#    = [[4,-2],[0,6]]
#
# dB = 3[[1,4],[-2,5]]
#    = [[3,12],[-6,15]]
#
#
# (c + d)A =
#       cA = 2[[2, -1], [0,3]]          dA = 3[[2,-1],[0,-3]]
#          = [[4,-2], [0,6]]               =  [[3,12],[-6,15]]
#
# A(c + d) = Ac + Ad  ,  as define above Ac = cA & Ad = dA
#
#         Ac = [4  -2]      Ad = [6 -3]
#              [0  -6]           [0  9]
#
#         Ac + Ad = [4 -2]    +   [6 -3]
#                   [0  6]        [0  9]
#
#                 = [10  -5]
#                   [0   15]
#
#
# (B) Properties of Scalar Multiplication
#     Associativity Property:
#             (c.d)A = C.(dA)
#              (c.d)A = 2*3([[2,-1],[0,3]])
#                     = 6[[2,-1],[0,3]]
# ```                 =  [[12, -6], [0, 18]]
#             c.(dA) = 2(3[[2,-1],[0,3]])
#                    = 2([6,-3],[0,9])
#                    = [[12, -6], [0,18]]
#
#     Distributive Property:
#        c(A + B) = 2([[2,-1],[0,3]] + [[1,4], [-2,5]] )
#                 = 2 ([[3,3], [-2,8]])
#                 =    [[6,6],[-4,16]]
#
#              cA = 2([[2,-1],[0,3]])
#                 =   [[4,-2], [0, 6]]
#
#              cB = 2([[1,4], [-2,5]])
#                 =   [[2,8], [-4,10]]
#
#             cA + cB = [[4,-2], [0, 6]]  +  [[2,8], [-4,10]]
#
#                     = [[6,6], [-4, 16]]
#
#     Scalar Addition:
#
#    (c+d)A =
#
#       cA = 2[[2, -1], [0,3]]     +     dA = 3[[2,-1],[0, 3]]
#
#          =      [[4,-2], [0,6]] + [[6,-3],[0, 9]]
#
#            (c+d)A = [10  -5]
#                     [0   15]
#
#
#             A(c + d) = Ac + Ad  ,  as define above Ac = cA & Ad = dA
#
#                         Ac = [4  -2]      Ad = [6 -3]
#                              [0  -6]           [0  9]
#
#                              Ac + Ad = [4 -2]    +   [6 -3]
#                                        [0  6]        [0  9]
#
#                                     = [10  -5]
#                                       [0   15]
#
# (c) A^T = [2    0]    Transpose Of A and B
#           [-1   3]
#     B^T = [1  -2]
#           [4   5]
#
#     det(A) = [2 -1]     =  ((2 x 3) - (0 x 3)) = 6-0 = 6      Determinant Of A and B
#              [0  3]
#     det(B) = [1  4]     =  (1 x 5) - (4 x -2)  = 5 + 8 = 13
#               [-2 5]
#
#     A^-1 = 1/6 [3 1]    = [1/2  1/6]      Inverse of A and B
#                [0 2]      [0    1/3]
#
#     B^-1 = 1/13 [5  -4]  = [5/13    -4/13]
#                 [2   1]    [2/13    1/13]
